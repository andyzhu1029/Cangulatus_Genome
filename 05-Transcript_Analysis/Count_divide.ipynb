# %%
with open('./Count_count_matrix.txt','r')as fi:
    for line in fi:
        item = line.strip().split('\t')
        if "CaA" in item[0]:
            with open('./CaA_count_matrix.txt','a')as fo:
                fo.write(line)
